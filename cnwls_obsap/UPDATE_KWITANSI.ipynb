# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/untitled3.csv', delimiter=';')


CompanyDB = "IGU_NEW" 
UserName =  "manager"
Password = "8610550"
url =  "https://192.168.250.40:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "Invoices("  + str(line[0]) + ")"
   
	payload = {
				"U_IDU_FPajak" : (line[1] ) 
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	print(urlbp)
	#print(payload)
	print(rsp.status_code)
	if rsp.status_code >=400 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.250.40:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '2b765946-9585-11ed-8000-089204b66136', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.250.40:50000/b1s/v1/Invoices(6509)
# {'U_Kw_No': 'SS20230100092'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6514)
# {'U_Kw_No': 'SS20230100094'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4663)
# {'U_Kw_No': 'SS20230100051'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6665)
# {'U_Kw_No': 'SS20230100098'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6666)
# {'U_Kw_No': 'SS20230100099'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6667)
# {'U_Kw_No': 'SS20230100100'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6668)
# {'U_Kw_No': 'SS20230100101'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4770)
# {'U_Kw_No': 'SS20230100103'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4773)
# {'U_Kw_No': 'SS20230100104'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4538)
# {'U_Kw_No': 'SS20230100076'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4539)
# {'U_Kw_No': 'SS20230100077'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4586)
# {'U_Kw_No': 'SS20230100079'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4587)
# {'U_Kw_No': 'SS20230100082'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6440)
# {'U_Kw_No': 'SS20230100087'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6441)
# {'U_Kw_No': 'SS20230100088'}
# https://192.168.250.40:50000/b1s/v1/Invoices(9513)
# {'U_Kw_No': 'SS20230100152'}
# https://192.168.250.40:50000/b1s/v1/Invoices(9514)
# {'U_Kw_No': 'SS20230100180'}
# https://192.168.250.40:50000/b1s/v1/Invoices(9515)
# {'U_Kw_No': 'SS20230100181'}
# https://192.168.250.40:50000/b1s/v1/Invoices(9176)
# {'U_Kw_No': 'SS20230100120'}
# https://192.168.250.40:50000/b1s/v1/Invoices(8972)
# {'U_Kw_No': 'SS20230100102'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6901)
# {'U_Kw_No': 'SS20230100108'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6902)
# {'U_Kw_No': 'SS20230100110'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6903)
# {'U_Kw_No': 'SS20230100111'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6904)
# {'U_Kw_No': 'SS20230100112'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6967)
# {'U_Kw_No': 'SS20230100095'}
# https://192.168.250.40:50000/b1s/v1/Invoices(6968)
# {'U_Kw_No': 'SS20230100097'}
# https://192.168.250.40:50000/b1s/v1/Invoices(7017)
# {'U_Kw_No': 'SS20230100114'}
# https://192.168.250.40:50000/b1s/v1/Invoices(7021)
# {'U_Kw_No': 'SS20230100115'}
# https://192.168.250.40:50000/b1s/v1/Invoices(7090)
# {'U_Kw_No': 'SS20230100122'}
# https://192.168.250.40:50000/b1s/v1/Invoices(7095)
# {'U_Kw_No': 'SS20230100118'}
# https://192.168.250.40:50000/b1s/v1/Invoices(7100)
# {'U_Kw_No': 'SS20230100121'}
# https://192.168.250.40:50000/b1s/v1/Invoices(11485)
# {'U_Kw_No': 'SS20230100172'}
# https://192.168.250.40:50000/b1s/v1/Invoices(11486)
# {'U_Kw_No': 'SS20230100179'}
# https://192.168.250.40:50000/b1s/v1/Invoices(9823)
# {'U_Kw_No': 'SS20230100195'}
# https://192.168.250.40:50000/b1s/v1/Invoices(4969)
# {'U_Kw_No': 'SS20230100116'}
# https://192.168.250.40:50000/b1s/v1/Invoices(5069)
# {'U_Kw_No': 'SS20230100125'}
# https://192.168.250.40:50000/b1s/v1/Invoices(5070)
# {'U_Kw_No': 'SS20230100125'}
# https://192.168.250.40:50000/b1s/v1/Invoices(8849)
# {'U_Kw_No': 'SS20230100093'}
# https://192.168.250.40:50000/b1s/v1/Invoices(8850)
# {'U_Kw_No': 'SS20230100089'}
# https://192.168.250.40:50000/b1s/v1/Invoices(8851)
# {'U_Kw_No': 'SS20230100090'}
# https://192.168.250.40:50000/b1s/v1/Invoices(7191)
# {'U_Kw_No': 'SS20230100106'}
