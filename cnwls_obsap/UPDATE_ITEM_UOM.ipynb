# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/oitm_uomORder.csv', delimiter=';')


CompanyDB = "LIVE_SOLOTEST" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "Items('"  + line[0] + "')"
   
	payload = {
				"SalesUnit" : (line[2] ),
				"PurchaseUnit" : (line[2] ) 
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	#print(urlbp)
	#print(payload)
	#print(rsp.status_code)
	if rsp.status_code ==400 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.6.23:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '149afec8-8c09-11ed-8000-089204b651d6', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.6.23:50000/b1s/v1/Items('AAU2JBS055')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AAU2MUL081')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AAU2MUL082')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AAU2MUL083')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AAU2MUL084')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AAU2MUL085')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AID2LOC064')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AID2LOC065')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AID2LOC066')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AID2LOC067')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AID2LOC068')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('AID2LOC069')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('FIT3GEO001')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
# https://192.168.6.23:50000/b1s/v1/Items('JID2BCH108')
# {'SalesUnit': nan, 'PurchaseUnit': nan}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': 'BadFormat'}}}
