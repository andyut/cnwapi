# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/api/cnwapi/cnwls_obsap/BK_UPDATE_OUTLET.csv', delimiter=';')


CompanyDB = "IGU2023" 
UserName =  "manager"
Password = "8610550"
url =  "https://192.168.250.10:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"

headers= {"B1S-ReplaceCollectionsOnPatch":"true"}
payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "BusinessPartners('" + line[0] +  "')"
	#iaddress = line[2] if line[2] else "-"
	payload = {  
				"BPAddresses":[
					{
						"AddressName": line[3],
						"AddressType": "bo_ShipTo",
						"U_Bill_Area": line[6]  
					} 
 
    			]
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)	
	print(urlbp)
	print(payload)
	print(rsp.status_code)
	if rsp.status_code >=300 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': 'dd4782b8-d75b-11ed-8000-1866dae8f350', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING KELAPA GADING FSDT', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK01'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING SENAYAN CITY', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK01'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING SKYLINE', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK02'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING GRAND INDONESIA', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK03'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING CILANDAK TOWN SQUARE', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK06'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING SUPERMALL KARAWACI', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK10'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING CENTRAL PARK', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK13'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING HAYAM WURUK', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK14'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING CIBUBUR SQUARE KM 10', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK15'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING GIANT BSD', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK17'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING BLOK M PLAZA', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK20'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING  BENOA SQUARE BALI', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK21'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING MAL CIPUTRA JAKARTA', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK23'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING SUNTER MALL', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK24'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING CIBUBUR FSDT-BEKASI', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK26'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING PARAMOUNT GADING SERPONG', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK27'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING DUREN SAWIT', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK28'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING BOTANI SQUARE', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK30'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING PANTAI INDAH KAPUK', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK32'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING SUNSET', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK35'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING REST AREA KM19', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK37'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING KASABLANKA', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK40'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING SETIABUDI ONE', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK43'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING PLAZA ATRIUM', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK44'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING THAMRIN CITY', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK45'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING REST AREA KM 13.5', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK46'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING LOTTE SHOPPING AVENUE', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK48'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING HYPERMALL BEKASI', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK49'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING  PLAZA FESTIVAL', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK50'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING PASARAYA BLOK M', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK51'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING REST AREA KM14', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK52'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING MALL OF INDONESIA (MOI)', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK53'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING BELLAGIO MALL', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK54'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING CITYWALK SUDIRMAN', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK60'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING TRANSMART CARREFOUR CEMPAKA PUTIH', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK61'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING TEBET FSDT', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK62'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': '(IN ACTIVE) BURGER KING TEBET GREEN', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK62'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING GANDARIA CITY', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK63'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING PERTAMINA GADING SERPONG', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK64'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING BALEKOTA MALL', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK65'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING REST AREA KM 97', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK68'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING KM 39 REST AREA TOL CIKAMPEK BEKASI', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK69'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING TERMINAL 3 ULTIMATE', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK70'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING GALUH MAS KARAWANG', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK71'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING LIPPO CIKARANG', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK72'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING PONDOK INDAH PLAZA', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'BK74'}]}
# 204
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('RQ0016')
# {'BPAddresses': [{'AddressName': 'BURGER KING BEC', 'AddressType': 'bo_ShipTo', 'U_Bill_Area': 'B