# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/api/cnwapi/cnwls_obsap/update_PPN08_sarkul.csv', delimiter=';')


CompanyDB = "SARKUL" 
UserName =  "manager"
Password = "8610550"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "Items('"  + line[0] + "')"
   
	payload = {
				"SalesVATGroup" : (line[4] ), 
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	print(urlbp)
	print(payload)
	print(rsp.status_code)
	if rsp.status_code >=400 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.6.23:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '4215df6e-c6fe-11ed-8000-089204b651d6', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.6.23:50000/b1s/v1/Items('AID02EUP0001')
# {'SalesVATGroup': 'PPNS8_27'}
# https://192.168.6.23:50000/b1s/v1/Items('CFR02FRC0002')
# {'SalesVATGroup': 'PPNS8_27'}
# https://192.168.6.23:50000/b1s/v1/Items('CFR02FRC0003')
# {'SalesVATGroup': 'PPNS8_27'}
# https://192.168.6.23:50000/b1s/v1/Items('CFR02FRC0006')
# {'SalesVATGroup': 'PPNS8_27'}
# https://192.168.6.23:50000/b1s/v1/Items('DNL02EUP0002')
# {'SalesVATGroup': 'PPNS8_18'}
# https://192.168.6.23:50000/b1s/v1/Items('EFR02MON0001')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('EFR02MON0002')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('EFR03FRC0005')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0001')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0002')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0003')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0004')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0005')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0006')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('FIT01EUP0007')
# {'SalesVATGroup': 'PPNS8_54'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0001')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0002')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0003')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0004')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0005')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0006')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0007')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0008')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0009')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0010')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0011')
# {'SalesVATGroup': 'PPNS8_53'}
# https://192.168.6.23:50000/b1s/v1/Items('ONZ02IQF0012')
# {'SalesVATGroup': 'PPNS8_53'}
