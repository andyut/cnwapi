# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/oitm_vat.csv', delimiter=';')


CompanyDB = "LIVE_SOLO" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "Items('"  + line[0] + "')"
   
	payload = {
				"SalesVATGroup" : (line[2] ),
				"PurchaseVATGroup" : (line[3] ) 
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	print(urlbp)
	print(payload)
	#print(rsp.status_code)
	if rsp.status_code ==400 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.6.23:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '55bf956a-8c10-11ed-8000-089204b651d6', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.6.23:50000/b1s/v1/Items('AAU02.MDF.001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU02.MDF.002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU02.MDF.003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC006')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC008')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC009')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC010')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC011')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC012')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC013')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC014')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC015')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC016')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC017')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC018')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC019')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC020')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC021')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC022')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC023')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC024')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC025')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC026')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC027')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC028')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC029')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC030')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC031')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC032')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC033')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC034')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC035')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AAC036')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMG001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMG002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH006')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AMH008')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AND001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1AND002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR006')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR008')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1BOR009')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1CSW001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1CSW002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1CSW003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1CSW005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1CSW006')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1CSW007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1DAR001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1DAR002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1DAR003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1DAR004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GBP001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GBP002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GHK001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GHK002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GHK003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRG001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRG002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRM001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRM002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRM003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRM004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1GRM005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV006')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV008')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV009')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV010')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV011')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV012')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV013')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV014')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV015')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV016')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV017')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV018')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV019')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV020')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV021')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV022')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV023')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV024')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV025')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV026')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV027')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV028')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV029')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV030')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV031')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV032')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV033')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV034')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV035')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV036')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV037')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV038')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV039')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV040')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV041')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV042')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV043')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV044')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV045')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV046')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV047')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV048')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV049')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV050')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV051')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV052')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HRV053')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HVM001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HVM002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1HVM003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS001')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS002')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS003')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS005')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS006')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS008')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS009')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS010')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS011')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1JBS012')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('AAU1

# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KID2SAR005')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KID2SAR006')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KID2SAR007')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KID5ANW001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('KUS3PIN001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KUS3PIN002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KUS3PIN003')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('KUS3PIN004')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO003')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO004')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO005')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO006')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO007')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO008')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO009')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO010')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO011')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO012')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO013')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO014')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO015')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO016')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO017')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO018')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO019')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO020')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO021')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO022')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO023')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO024')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO025')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO026')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO027')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO028')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO029')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO030')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO031')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO032')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO033')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO034')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MAT3DBO035')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MCN3WZB001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG003')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG004')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG005')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG006')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG007')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG008')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG009')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG010')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG011')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG012')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG013')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG014')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG015')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG016')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG017')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG018')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG019')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3BRG020')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MDE3HEL001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.004')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.007')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.008')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.010')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.011')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.013')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.017')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.018')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.022')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.023')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.024')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.025')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.026')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.028')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.029')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.033')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.034')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.041')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.042')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.043')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.044')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.051')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.053')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.054')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.058')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.059')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.061')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.062')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.068')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID03.HAD.095')
# {'SalesVATGroup': 'PPNK_08', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD003')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD004')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD005')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD006')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD007')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD008')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD009')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD010')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD011')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD012')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD013')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD014')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MID3MAD015')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MSG3ROB001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MSG3ROB002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MSG3ROB003')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MUS2CJR001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MUS3BBR001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MUS3FIS001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('MUS3FIS002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('OID3LOC014')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM01'}
# https://192.168.6.23:50000/b1s/v1/Items('OSP03.OIL.106')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('OSP03.OIL.107')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('OSP03.OIL.109')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('OSP03.OIL.112')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('PBR.MLSC.001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('PBR.WUC.005')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('PBR.WUHTC.006')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('PIT03.CASA.102')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('PIT03.CASA.110')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('PIT03.PST.501')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('RAU.MIG01.0001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('RAU.MIG01.0013')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('RAU03.PRB.0005')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('RCA03.MMR.002')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('RIN03.KONS.015')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('RIN03.KONS.021')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('SOL.CDY.0001')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
# https://192.168.6.23:50000/b1s/v1/Items('SOL.CDY.0007')
# {'SalesVATGroup': 'PPN_01', 'PurchaseVATGroup': 'PPNM_08'}
