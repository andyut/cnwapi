# %%
import json
import requests
import pandas as pd
import numpy


from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

#data = {'temperature':'24.3'}
#data_json = json.dumps(data)

df = pd.read_csv('/data/cnwls/cnwls_obsap/SOLO_AP2.csv', delimiter=';')

mylist = df.values.tolist()
 

appSession = requests.Session()

#########################
# LOGIN
#########################

url = "https://192.168.6.23:50000/b1s/v1/Login"


payload = { "CompanyDB" :"LIVE_SOLO3" ,
			"UserName" : "manager" ,
			"Password" : "12345"
			}
response = appSession.post(url, json=payload,verify=False)

#print(response.text)


#########################
# ADD CUSTOMER 
#########################


url = "https://192.168.6.23:50000/b1s/v1/PurchaseInvoices"

for line in mylist : 
	 
	#print(str(line[11]))
# 	address = line[12] if line[12] else "-"
# 	outlet  = line[11] if line[11] else line[1]
# 	mailaddress = line[10] if line[10] else "-" 
# 	npwp = line[9] if line[9] else "" 
# 	print(outlet)
	payload = {
				"DocType" : "dDocument_Service",
				"DocDate" : line[1],
				"DocDueDate" : line[2],
				"TaxDate" : line[3], 
				"CardCode" : line[0],
				"CardName" : line[4],
				"NumAtCard" : line[7],
				"Reference1" : line[7],
				"Reference2" : line[9],
				"Comments" : line[9],
				"JournalMemo" : line[9],
				"DocumentLines" : [
					{
						"ItemDescription":line[9],
						"Price" : line[11],
						"LineTotal" : line[11],
						"Currency" :"IDR",
						"AccountCode": "3910003",
						"VatGroup": "PPNM_00"
					}
				]
			}               
	#print(line[0])
	#print(payload)
	rsp = appSession.post(url,json=payload,verify=False)
	if rsp.status_code >=400:
		print(rsp.json())	
# 	print(line[0])
	#print(rsp.json())

	#apdp = rsp.json()
	





	 
# 
#response_Json = r.json() 
#print(type(json.dumps(payload)))
#print(r)
#print(response_Json)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/cnwls/cnwls_obsap/solo ob ap.ipynb Cell 1 in <cell line: 32>()
#      <a href='vscode-notebook-cell:/data/cnwls/cnwls_obsap/solo%20ob%20ap.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> url = "https://192.168.6.23:50000/b1s/v1/Login"
#      <a href='vscode-notebook-cell:/data/cnwls/cnwls_obsap/solo%20ob%20ap.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> payload = { "CompanyDB" :"LIVE_SOLO3" ,
#      <a href='vscode-notebook-cell:/data/cnwls/cnwls_obsap/solo%20ob%20ap.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> 			"UserName" : "manager" ,
# ...
