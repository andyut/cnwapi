# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/oitm_uomORder.csv', delimiter=';')


CompanyDB = "LIVE_SOLOTEST" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "UOM_ORDER"
   
	payload = {
				"Code" : (line[0]),
				"Name" : (line[1]),
				"UOM_DETAILCollection" : 
									[{
										"Code" : line[0] ,
										"U_Item_Code" : line[0] ,
										"U_Uom_Order" : line[2] ,
										"U_Qty_Convert" : 1
									}]
			}               

	rsp = appSession.post(urlbp,json=payload,verify=False)
	print(urlbp)
	print(payload)
	#print(rsp.status_code)
	if rsp.status_code ==400 :
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.6.23:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': 'eb147638-8c08-11ed-8000-089204b651d6', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.6.23:50000/b1s/v1/UOM_ORDER
# {'Code': 'AAU02.MDF.001', 'Name': 'AUS FROZEN TENDERLOIN MIDFIELD', 'UOM_DETAILCollection': [{'Code': 'AAU02.MDF.001', 'U_Item_Code': 'AAU02.MDF.001', 'U_Uom_Order': 'KG', 'U_Qty_Convert': 1}]}
# {'error': {'code': -2035, 'message': {'lang': 'en-us', 'value': 'This entry already exists in the following tables (ODBC -2035)'}}}
# https://192.168.6.23:50000/b1s/v1/UOM_ORDER
# {'Code': 'AAU02.MDF.002', 'Name': 'AUS FROZEN RIBEYE MIDFIELD', 'UOM_DETAILCollection': [{'Code': 'AAU02.MDF.002', 'U_Item_Code': 'AAU02.MDF.002', 'U_Uom_Order': 'KG', 'U_Qty_Convert': 1}]}
# {'error': {'code': -2035, 'message': {'lang': 'en-us', 'value': 'This entry already exists in the following tables (ODBC -2035)'}}}
# https://192.168.6.23:50000/b1s/v1/UOM_ORDER
# ...
