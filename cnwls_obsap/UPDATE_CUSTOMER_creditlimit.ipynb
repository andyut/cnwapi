# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/solo_customer_creditlimit.csv', delimiter=';')


CompanyDB = "LIVE_SOLO" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"

headers= {"B1S-ReplaceCollectionsOnPatch":"true"}
payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "BusinessPartners('" + line[0] +  "')"
	#iaddress = line[2] if line[2] else "-"
	payload = { "CreditLimit" : line[1],
				"MaxCommitment": line[1]
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	# print(urlbp)
	#print(payload)
	#print(rsp.status_code)
	if rsp.status_code ==400 :
		print(urlbp)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.6.23:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': 'e42c816c-8d70-11ed-8000-089204b651d6', 'Version': '1000180', 'SessionTimeout': 30}

# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/solo_customer_creditlimit.csv', delimiter=';')


CompanyDB = "LIVE_SOLO" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"

headers= {"B1S-ReplaceCollectionsOnPatch":"true"}
payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "BusinessPartners('" + line[0] +  "')"
	#iaddress = line[2] if line[2] else "-"
	payload = { "CreditLimit" : line[1],
				"MaxCommitment": line[1]
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	# print(urlbp)
	#print(payload)
	#print(rsp.status_code)
	if rsp.status_code ==400 :
		print(urlbp)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.6.23:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': 'e42c816c-8d70-11ed-8000-089204b651d6', 'Version': '1000180', 'SessionTimeout': 30}
