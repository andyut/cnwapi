# %%
import requests
import json
import numpy as np
import pandas as pd
import pandas.io.sql
import pymssql    


from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/api/cnwapi/cnwls_obsap/whs/WHS.csv', delimiter=';')
 

mylist = df.values.tolist()


CompanyDB = "IGURACKING" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.250.10:50000/b1s/v1/"
 

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# whs add 
#########################

for line in mylist : 

	urlbp = url + "Warehouses"
   
	payload = {
				"WarehouseCode" : line[0],
				"WarehouseName" : line[1],
				"EnableBinLocations" : "tYES",
				"Location" :line[2]
			}               

	rsp = appSession.post(urlbp,json=payload,verify=False)
	print(urlbp)
	#print(payload)
	print(rsp.status_code)
	if rsp.status_code >=400 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '072b4a38-de91-11ed-803a-1866dae8f350', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 400
# https://192.168.250.10:50000/b1s/v1/Warehouses
# {'WarehouseCode': 'B3G11', 'WarehouseName': 'TARUNA-GDG BARU-G11', 'EnableBinLocations': 'tYES', 'Location': 2}
# {'error': {'code': -2035, 'message': {'lang': 'en-us', 'value': 'This entry already exists in the following tables (ODBC -2035)'}}}
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
# https://192.168.250.10:50000/b1s/v1/Warehouses
# 201
