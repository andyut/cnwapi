# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

data1 = """
				[
				{
					"ItmsGrpCod": 102,
					"GroupName": "DELICATESSENS",
					"WIPMaterialVarianceAccount": 1190002,
					"ReturningAccount": 1190002,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110002,
					"InventoryAccount": 1190002,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190002,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190002,
					"VarianceAccount": 5210003,
					"CostAccount": 5110002,
					"PurchaseCreditAcc": 5110002,
					"SalesCreditAcc": 4120002,
					"NegativeInventoryAdjustmentAccount": 5110002
				},
				{
					"ItmsGrpCod": 103,
					"GroupName": "POULTRY",
					"WIPMaterialVarianceAccount": 1190003,
					"ReturningAccount": 1190003,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110003,
					"InventoryAccount": 1190003,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190003,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190003,
					"VarianceAccount": 5210003,
					"CostAccount": 5110003,
					"PurchaseCreditAcc": 5110003,
					"SalesCreditAcc": 4120003,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 104,
					"GroupName": "SEAFOOD",
					"WIPMaterialVarianceAccount": 1190004,
					"ReturningAccount": 1190004,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110004,
					"InventoryAccount": 1190004,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190004,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190004,
					"VarianceAccount": 5210003,
					"CostAccount": 5110004,
					"PurchaseCreditAcc": 5110004,
					"SalesCreditAcc": 4120004,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 105,
					"GroupName": "GROCERY",
					"WIPMaterialVarianceAccount": 1190005,
					"ReturningAccount": 1190005,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110005,
					"InventoryAccount": 1190005,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190005,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190005,
					"VarianceAccount": 5210003,
					"CostAccount": 5110005,
					"PurchaseCreditAcc": 5110005,
					"SalesCreditAcc": 4120005,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 106,
					"GroupName": "CONDIMENT AND SAUCE",
					"WIPMaterialVarianceAccount": 1190006,
					"ReturningAccount": 1190006,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110006,
					"InventoryAccount": 1190006,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190006,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190006,
					"VarianceAccount": 5210003,
					"CostAccount": 5110006,
					"PurchaseCreditAcc": 5110006,
					"SalesCreditAcc": 4120006,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 107,
					"GroupName": "VEGETABLES",
					"WIPMaterialVarianceAccount": 1190007,
					"ReturningAccount": 1190007,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110007,
					"InventoryAccount": 1190007,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190007,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190007,
					"VarianceAccount": 5210003,
					"CostAccount": 5110007,
					"PurchaseCreditAcc": 5110007,
					"SalesCreditAcc": 4120007,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 108,
					"GroupName": "DAIRY PRODUCTS",
					"WIPMaterialVarianceAccount": 1190008,
					"ReturningAccount": 1190008,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110008,
					"InventoryAccount": 1190008,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190008,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190008,
					"VarianceAccount": 5210003,
					"CostAccount": 5110008,
					"PurchaseCreditAcc": 5110008,
					"SalesCreditAcc": 4120008,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 109,
					"GroupName": "BEVERAGES & FRUIT",
					"WIPMaterialVarianceAccount": 1190009,
					"ReturningAccount": 1190009,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110009,
					"InventoryAccount": 1190009,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190009,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190009,
					"VarianceAccount": 5210003,
					"CostAccount": 5110009,
					"PurchaseCreditAcc": 5110009,
					"SalesCreditAcc": 4120009,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 110,
					"GroupName": "HERBS & SPICIES",
					"WIPMaterialVarianceAccount": 1190010,
					"ReturningAccount": 1190010,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110001,
					"InventoryAccount": 1190010,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190010,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190010,
					"VarianceAccount": 5210003,
					"CostAccount": 5110001,
					"PurchaseCreditAcc": 5110001,
					"SalesCreditAcc": 4120001,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 111,
					"GroupName": "BAKERY & PASTRY",
					"WIPMaterialVarianceAccount": 1190011,
					"ReturningAccount": 1190011,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110011,
					"InventoryAccount": 1190011,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190011,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190011,
					"VarianceAccount": 5210003,
					"CostAccount": 5110011,
					"PurchaseCreditAcc": 5110011,
					"SalesCreditAcc": 4120011,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 112,
					"GroupName": "NON FOOD",
					"WIPMaterialVarianceAccount": 1190012,
					"ReturningAccount": 1190012,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110012,
					"InventoryAccount": 1190012,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190012,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190012,
					"VarianceAccount": 5210003,
					"CostAccount": 5110012,
					"PurchaseCreditAcc": 5110012,
					"SalesCreditAcc": 4120012,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 113,
					"GroupName": "CONFECTIONERY",
					"WIPMaterialVarianceAccount": 1190013,
					"ReturningAccount": 1190013,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110013,
					"InventoryAccount": 1190013,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190013,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190013,
					"VarianceAccount": 5210003,
					"CostAccount": 5110013,
					"PurchaseCreditAcc": 5110013,
					"SalesCreditAcc": 4120013,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 114,
					"GroupName": "OTHERS",
					"WIPMaterialVarianceAccount": 1190012,
					"ReturningAccount": 1190012,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110012,
					"InventoryAccount": 1190012,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190012,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190012,
					"VarianceAccount": 5210003,
					"CostAccount": 5110012,
					"PurchaseCreditAcc": 5110012,
					"SalesCreditAchttps://outlook.live.com/mail/0/junkemailtoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 115,
					"GroupName": "FINE GOODS",
					"WIPMaterialVarianceAccount": 1190012,
					"ReturningAccount": 1190012,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110012,
					"InventoryAccount": 1190012,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190012,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190012,
					"VarianceAccount": 5210003,
					"CostAccount": 5110001,
					"PurchaseCreditAcc": 5110001,
					"SalesCreditAcc": 4120012,
					"NegativeInventoryAdjustmentAccount": 5210003
				},
				{
					"ItmsGrpCod": 116,
					"GroupName": "PASTRY",
					"WIPMaterialVarianceAccount": 1190010,
					"ReturningAccount": 1190010,
					"ExpensesAccount": 5210002,
					"RevenuesAccount": 4110010,
					"InventoryAccount": 1190010,
					"DecreaseGLAccount": 5210001,
					"GoodsClearingAccount": 1190010,
					"IncreaseGLAccount": 5210001,
					"WIPMaterialAccount": 1190010,
					"VarianceAccount": 5210003,
					"CostAccount": 5110010,
					"PurchaseCreditAcc": 5110010,
					"SalesCreditAcc": 4120010,
					"NegativeInventoryAdjustmentAccount": 5210003
				}
				]
				"""
data = json.loads(data1)


CompanyDB = "PTSCA" 
UserName =  "manager"
Password = "password"
url =  "https://192.168.250.10:50000/b1s/v1/"


appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"

headers= {"B1S-ReplaceCollectionsOnPatch":"true"}
payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())
urlItemGroup=""
print(type(data))
for line in data: 
	urlItemGroup = url + "ItemGroups(" + str(line["ItmsGrpCod"]) +  ")"
	print(line["ItmsGrpCod"])
	payload = { 	"GroupName" :line["GroupName"],
					"WIPMaterialVarianceAccount" :line["WIPMaterialVarianceAccount"],
					"ReturningAccount" :line["ReturningAccount"],
					"ExpensesAccount" :line["ExpensesAccount"],
					"RevenuesAccount" : line["RevenuesAccount"],
					"InventoryAccount" : line["InventoryAccount"],
					"DecreaseGLAccount" : line["DecreaseGLAccount"],
					"GoodsClearingAccount" : line["GoodsClearingAccount"],
					"IncreaseGLAccount" : line["IncreaseGLAccount"],
					"WIPMaterialAccount" : line["WIPMaterialAccount"],
					"VarianceAccount" : line["VarianceAccount"],
					"CostAccount" : line["CostAccount"],
					"PurchaseCreditAcc" : line["PurchaseCreditAcc"],
					"SalesCreditAcc" : line["SalesCreditAcc"],
					"NegativeInventoryAdjustmentAccount" : line["NegativeInventoryAdjustmentAccount"] 
			}
	rsp = appSession.patch(urlItemGroup,json=payload,verify=False)
	print(rsp.status_code)
	print(rsp.json())
	print(payload)


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '803aad0e-b4d6-11ed-8000-1866dae8f350', 'Version': '1000180', 'SessionTimeout': 30}
# <class 'list'>
# 102
# 404
# {'error': {'code': -2028, 'message': {'lang': 'en-us', 'value': "10001491 -  [OITB.VarianceAc] , 'No matching records found (ODBC -2028)'"}}}
# {'GroupName': 'DELICATESSENS', 'WIPMaterialVarianceAccount': 1190002, 'ReturningAccount': 1190002, 'ExpensesAccount': 5210002, 'RevenuesAccount': 4110002, 'InventoryAccount': 1190002, 'DecreaseGLAccount': 5210001, 'GoodsClearingAccount': 1190002, 'IncreaseGLAccount': 5210001, 'WIPMaterialAccount': 1190002, 'VarianceAccount': 5210003, 'CostAccount': 5110002, 'PurchaseCreditAcc': 5110002, 'SalesCreditAcc': 4120002, 'NegativeInventoryAdjustmentAccount': 5110002}
# 103
# 404
# {'error': {'code': -2028, 'message': {'lang': 'en-us', 'value': "10001491 -  [OITB.VarianceAc] , 'No matching records found (ODBC -2028)'"}}}
# ...
