# %%
import json
import requests
import pandas as pd
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

df = pd.read_csv('/data/cnwls/cnwls_obsap/update_customer.csv', delimiter=';')


CompanyDB = "LIVE_SOLO" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.6.23:50000/b1s/v1/"

mylist = df.values.tolist()

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

#print(response.text)


#########################
# UPDATE CUSTOMER 
#########################




for line in mylist : 

	urlbp = url + "BusinessPartners('" + line[0] + "') "
   
	payload = {
				"SalesPersonCode" : int(line[5]),
				"PayTermsGrpCode" : int(line[8])
			}               

	rsp = appSession.patch(urlbp,json=payload,verify=False)
	print(urlbp)
	print(payload)
	print(rsp.status_code)
	if rsp.status_code ==400 :
		print(rsp.json())

	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)




	 
# 
#response_Json = r.json() 
#print(type(json.dumps(payload)))
#print(r)
#print(response_Json)
# Out:
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0201')
# {'SalesPersonCode': 30, 'PayTermsGrpCode': 4}
# 400
# {'error': {'code': -5002, 'message': {'lang': 'en-us', 'value': '1320000199 - Sales employee has already been removed; select another sales employee [OHEM.salesPrson]'}}}
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0202')
# {'SalesPersonCode': 31, 'PayTermsGrpCode': 4}
# 400
# {'error': {'code': -5002, 'message': {'lang': 'en-us', 'value': '1320000199 - Sales employee has already been removed; select another sales employee [OHEM.salesPrson]'}}}
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('FC0003')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0003')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0025')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0008')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0010')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0006')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0038')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0042')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0044')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0069')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0043')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0007')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0023')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0006')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0362')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0087')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0092')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0094')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0014')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0104')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0108')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0014')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0017')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0364')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0121')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0124')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0011')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0132')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0040')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0026')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0292')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0042')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0143')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0145')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0050')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0152')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0028')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0159')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0029')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0167')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0170')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0171')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0034')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0181')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0184')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0187')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0192')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0194')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0199')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0035')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0042')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0215')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0219')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0226')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0028')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0239')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0267')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0278')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0044')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0256')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0287')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0062')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0298')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0299')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0308')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0309')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0311')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0014')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0050')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0333')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0060')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0336')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0193')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0351')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0352')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0353')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0354')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0001')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0111')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0149')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0318')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0335')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0051')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0367')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0011')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0032')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0114')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0038')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0249')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0061')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0043')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0304')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0314')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0053')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0030')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0034')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0001')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0003')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0032')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0116')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0031')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0055')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0040')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0272')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0031')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0038')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0046')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0048')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0004')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0021')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0020')
# {'SalesPersonCode': 77, 'PayTermsGrpCode': 9}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0062')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 10}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0366')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0003')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0004')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0006')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0004')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0009')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0009')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0012')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0016')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0008')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0018')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0021')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0045')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0070')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0071')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0065')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0083')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0088')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0095')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0015')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0009')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0011')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0018')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0118')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0130')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0133')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0039')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0136')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0027')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0138')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0048')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0049')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0153')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0156')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0013')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('DS0015')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0172')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0011')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0176')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0263')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0169')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('FC0001')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0189')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0195')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0200')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0036')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0038')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0207')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0208')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0209')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0211')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0212')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0220')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0227')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0231')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('HT0029')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0268')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0273')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0279')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0281')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0284')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0286')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('CT0009')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0063')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0300')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('FC0004')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0056')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0315')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0319')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0321')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0322')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0049')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0331')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0332')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0371')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0067')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0372')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('CT0007')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('CT0008')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('UM0051')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0357')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0358')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 4}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0010')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0003')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0005')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0077')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0113')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0122')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('PC0036')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 6}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0022')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0049')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0066')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS0098')
# {'SalesPersonCode': 78, 'PayTermsGrpCode': 7}
# 204
# https://192.168.6.23:50000/b1s/v1/BusinessPartners('RS