# %%
import requests
import json
import numpy as np
import pandas as pd
import pandas.io.sql
import pymssql    


from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)


df = pd.read_csv('/data/api/cnwapi/cnwls_obsap/invar/BP_UDF.csv', delimiter=';')

 

mylist = df.values.tolist()


CompanyDB = "IGU_NEW" 
UserName =  "manager"
Password = "8610550"
url =  "https://192.168.250.40:50000/b1s/v1/"
 

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# whs add 
#########################
 

#########################
# UPDATE UOM ORDER 
#########################




for line in mylist : 

	urlbp = url + "BusinessPartners('" + line[0] +  "')"
	#iaddress = line[2] if line[2] else "-"
	payload = {  
				 "U_PrintFaktur" : line[7],
				 "U_Invoicing" : line[7],
				 "U_PrintFP" : line[5],
				 "U_PrintKwitansi" :line[10] 
			}    
	         

	rsp = appSession.patch(urlbp,json=payload,verify=False)	
	#print(urlbp)
	#print(payload)
	#print(rsp.status_code)
	if rsp.status_code >=300 :
		print(urlbp)
		print(payload)
		print(rsp.json())

	#apdp = rsp.json()



urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': 'bc71c352-f482-11ed-8000-1866dae8f350', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.250.10:50000/b1s/v1/BusinessPartners('ps0371')
# {'U_PrintFaktur': 'N', 'U_Invoicing': 'N', 'U_PrintFP': 'N', 'U_PrintKwitansi': 'Y'}
# {'error': {'code': -1, 'message': {'lang': 'en-us', 'value': "[Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Cannot insert the value NULL into column 'CardCode', table 'IGU202305.dbo.OCRD'; column does not allow nulls. INSERT fails."}}}
