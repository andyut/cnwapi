# %%
import requests
import json
import numpy as np
import pandas as pd
import pandas.io.sql
import pymssql    


from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

 


CompanyDB = "IGURACKING" 
UserName =  "manager"
Password = "12345"
url =  "https://192.168.250.10:50000/b1s/v1/"
 

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# whs add 
#########################
 

urlbp = url + "UserFieldsMD"

# PRINT FAKTUR
payload = 	{
			 "Name" : "PrintFaktur" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Print Faktur",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"Y",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
             ]
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 

# PRINT KWITANSI
payload = 	{
			 "Name" : "PrintKwitansi" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Print Kwitansi",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"N",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
				{
					"Value" : "O",
					"Description" : "Yes, Per Outlet"
				},                
             ]
             
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 


# PRINT FP
payload = 	{
			 "Name" : "PrintFP" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Print Faktur Pajak",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"Y",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
             ]
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 
	#apdp = rsp.json()


urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '771cd09e-f39c-11ed-8000-1866dae8f350', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.250.10:50000/b1s/v1/UserFieldsMD
# {'Name': 'PrintFaktur', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur', 'SubType': 'st_None', 'TableName': 'OCRD', 'DefaultValue': 'Y', 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
# 201
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#UserFieldsMD/@Element', 'Name': 'PrintFaktur', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur', 'SubType': 'st_None', 'LinkedTable': None, 'DefaultValue': 'Y', 'TableName': 'OCRD', 'FieldID': 37, 'EditSize': 10, 'Mandatory': 'tNO', 'LinkedUDO': None, 'LinkedSystemObject': None, 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
# https://192.168.250.10:50000/b1s/v1/UserFieldsMD
# {'Name': 'PrintKwitansi', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Kwitansi', 'SubType': 'st_None', 'TableName': 'OCRD', 'DefaultValue': 'N', 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}, {'Value': 'O', 'Description': 'Yes, Per Outlet'}]}
# 201
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#UserFieldsMD/@Element', 'Name': 'PrintKwitansi', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Kwitansi', 'SubType': 'st_None', 'LinkedTable': None, 'DefaultValue': 'N', 'TableName': 'OCRD', 'FieldID': 38, 'EditSize': 10, 'Mandatory': 'tNO', 'LinkedUDO': None, 'LinkedSystemObject': None, 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}, {'Value': 'O', 'Description': 'Yes, Per Outlet'}]}
# https://192.168.250.10:50000/b1s/v1/UserFieldsMD
# {'Name': 'PrintFP', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur Pajak', 'SubType': 'st_None', 'TableName': 'OCRD', 'DefaultValue': 'Y', 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
# 201
# {'odata.metadata': 'https://192.168.250.10:50000/b1s/v1/$metadata#UserFieldsMD/@Element', 'Name': 'PrintFP', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur Pajak', 'SubType': 'st_None', 'LinkedTable': None, 'DefaultValue': 'Y', 'TableName': 'OCRD', 'FieldID': 39, 'EditSize': 10, 'Mandatory': 'tNO', 'LinkedUDO': None, 'LinkedSystemObject': None, 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
