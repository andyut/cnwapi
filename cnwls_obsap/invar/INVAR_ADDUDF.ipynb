# %%
import requests
import json
import numpy as np
import pandas as pd
import pandas.io.sql
import pymssql    


from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

 


CompanyDB = "IGU_LIVE_20221204" 
UserName =  "manager"
Password = "8610550"
url =  "https://192.168.250.40:50000/b1s/v1/"
 

#print(mylist)

appSession = requests.Session()

#########################
# LOGIN
#########################

urllogin = url + "Login"


payload = { "CompanyDB" :CompanyDB ,
			"UserName" : UserName,
			"Password" : Password
			}
response = appSession.post(urllogin, json=payload,verify=False)

print(response.json())


#########################
# whs add 
#########################
 

urlbp = url + "UserFieldsMD"

# PRINT FAKTUR
payload = 	{
			 "Name" : "PrintFaktur" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Print Faktur",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"Y",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
             ]
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 

# PRINT KWITANSI
payload = 	{
			 "Name" : "PrintKwitansi" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Print Kwitansi",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"N",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
				{
					"Value" : "O",
					"Description" : "Yes, Per Outlet"
				},     
				{
					"Value" : "P",
					"Description" : "Yes, Per PO"
				},                            
             ]
             
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 


# PRINT FP
payload = 	{
			 "Name" : "PrintFP" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Print Faktur Pajak",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"Y",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
             ]
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 
	#apdp = rsp.json()

# WAJIB PO
payload = 	{
			 "Name" : "Wajib_PO" ,
			 "Type" : "db_Alpha",
			 "Size" : 10 ,
			 "Description" : "Wajib PO",
			 "SubType" :"st_None",
			 "TableName" : "OCRD",
             "DefaultValue" :"Y",
             "ValidValuesMD" : 
             [
                 {
                 "Value" : "Y",
                 "Description" : "Yes"
			 	},
				{
					"Value" : "N",
					"Description" : "No"
				},
             ]
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 


# VIRTUAL REK
payload = 	{
			 "Name" : "IGU_virtualrek" ,
			 "Type" : "db_Alpha",
			 "Size" : 20 ,
			 "Description" : "Rek Virtual",
			 "SubType" :"st_None",
			 "TableName" : "OCRD" 
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 


# PARENT GROUP
payload = 	{
			 "Name" : "Parent_Group" ,
			 "Type" : "db_Alpha",
			 "Size" : 25 ,
			 "Description" : "Parent Group",
			 "SubType" :"st_None",
			 "TableName" : "OCRD" 
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 


# print_va
payload = 	{
			 "Name" : "print_va" ,
			 "Type" : "db_Alpha",
			 "Size" : 25 ,
			 "Description" : "Parent Group",
			 "SubType" :"st_None",
			 "TableName" : "OCRD" 
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 

# Invoicing
payload = 	{
			 "Name" : "Invoicing" ,
			 "Type" : "db_Alpha",
			 "Size" : 25 ,
			 "Description" : "Parent Group",
			 "SubType" :"st_None",
			 "TableName" : "OCRD" 
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 

# Invoicing
payload = 	{
			 "Name" : "PenagihanType" ,
			 "Type" : "db_Alpha",
			 "Size" : 50 ,
			 "Description" : "Parent Group",
			 "SubType" :"st_None",
			 "TableName" : "OCRD" 
			}               

rsp = appSession.post(urlbp,json=payload,verify=False)
print(urlbp)
print(payload)
print(rsp.status_code)

print(rsp.json()) 
urllogout = url + "Logout"
rsplogout = appSession.post(urllogout,json=payload,verify=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# {'odata.metadata': 'https://192.168.250.40:50000/b1s/v1/$metadata#B1Sessions/@Element', 'SessionId': '12b2a216-0128-11ee-8000-089204b66136', 'Version': '1000180', 'SessionTimeout': 30}
# https://192.168.250.40:50000/b1s/v1/UserFieldsMD
# {'Name': 'PrintFaktur', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur', 'SubType': 'st_None', 'TableName': 'OCRD', 'DefaultValue': 'Y', 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
# 201
# {'odata.metadata': 'https://192.168.250.40:50000/b1s/v1/$metadata#UserFieldsMD/@Element', 'Name': 'PrintFaktur', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur', 'SubType': 'st_None', 'LinkedTable': None, 'DefaultValue': 'Y', 'TableName': 'OCRD', 'FieldID': 38, 'EditSize': 10, 'Mandatory': 'tNO', 'LinkedUDO': None, 'LinkedSystemObject': None, 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
# https://192.168.250.40:50000/b1s/v1/UserFieldsMD
# {'Name': 'PrintKwitansi', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Kwitansi', 'SubType': 'st_None', 'TableName': 'OCRD', 'DefaultValue': 'N', 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}, {'Value': 'O', 'Description': 'Yes, Per Outlet'}, {'Value': 'P', 'Description': 'Yes, Per PO'}]}
# 201
# {'odata.metadata': 'https://192.168.250.40:50000/b1s/v1/$metadata#UserFieldsMD/@Element', 'Name': 'PrintKwitansi', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Kwitansi', 'SubType': 'st_None', 'LinkedTable': None, 'DefaultValue': 'N', 'TableName': 'OCRD', 'FieldID': 39, 'EditSize': 10, 'Mandatory': 'tNO', 'LinkedUDO': None, 'LinkedSystemObject': None, 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}, {'Value': 'O', 'Description': 'Yes, Per Outlet'}, {'Value': 'P', 'Description': 'Yes, Per PO'}]}
# https://192.168.250.40:50000/b1s/v1/UserFieldsMD
# {'Name': 'PrintFP', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur Pajak', 'SubType': 'st_None', 'TableName': 'OCRD', 'DefaultValue': 'Y', 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
# 201
# {'odata.metadata': 'https://192.168.250.40:50000/b1s/v1/$metadata#UserFieldsMD/@Element', 'Name': 'PrintFP', 'Type': 'db_Alpha', 'Size': 10, 'Description': 'Print Faktur Pajak', 'SubType': 'st_None', 'LinkedTable': None, 'DefaultValue': 'Y', 'TableName': 'OCRD', 'FieldID': 40, 'EditSize': 10, 'Mandatory': 'tNO', 'LinkedUDO': None, 'LinkedSystemObject': None, 'ValidValuesMD': [{'Value': 'Y', 'Description': 'Yes'}, {'Value': 'N', 'Description': 'No'}]}
